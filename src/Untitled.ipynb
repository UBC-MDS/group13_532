# %%
from dash import Dash, html, dcc, Input, Output
import altair as alt
import dash_bootstrap_components as dbc
import pandas as pd

alt.data_transformers.disable_max_rows()
# Out:
# /Users/jasmineortega/opt/miniconda3/envs/532/lib/python3.10/site-packages/dash_bootstrap_components/_table.py:5: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html
# DataTransformerRegistry.enable('default')

# %%
data = pd.read_csv("../data/processed/clean_df.csv")
data["cast_list"] = data["cast"].str.split(",")
data["cast_count"] = data["cast_list"].str.len()
cast_df = data[["title", "cast", "listed_in", "cast_count", "rating", "release_year"]]
cast_df
# Out:
#                                     title  \
# 0     Guatemala: Heart of the Mayan World
# 1                         The Zoya Factor
# 2                               Atlantics
# 3                            Crazy people
# 4                          I Lost My Body
# ...                                   ...
# 3934                        Even the Rain
# 3935          Mad Ron's Prevues from Hell
# 3936                             Splatter
# 3937              Just Another Love Story
# 3938                 To and From New York
#
#                                                    cast  \
# 0                                     Christian Morales
# 1     Sonam Kapoor, Dulquer Salmaan, Sanjay Kapoor, ...
# 2     Mama Sane, Amadou Mbow, Ibrahima Traore, Nicol...
# 3     Ramsey Nouah, Chigul, Sola Sobowale, Ireti Doy...
# 4     Hakim Faris, Victoire Du Bois, Patrick d'Assum...
# ...                                                 ...
# 3934  Luis Tosar, Gael García Bernal, Juan Carlos Ad...
# ...

# %%
cast_df.to_csv("../jasmine_df.csv")

# %%
data[["mins", "trash"]] = data["duration"].str.split(' ', expand=True)
data["mins"].dropna()
bk_df = data[["rating", "mins", "release_year"]]
bk_df

backup = alt.Chart(bk_df, 
                   title = "Movie Rating over Avg. Film Length").mark_point(
                    ).encode(x = alt.X("mean(mins)",
                            axis=alt.Axis(format='n'),
                                      title = "Avg Film Length"), 
                              y = alt.Y("rating:N", 
                                title = "Film Rating"))
backup
# Out:
# alt.Chart(...)

# %%
def plot_bkup(ycol):
    
    backup = alt.Chart(bk_df, 
                   title = "Movie Rating over Avg. Film Length").mark_circle(
                    ).encode(x = alt.X("mean(mins)",
                            axis=alt.Axis(format='n'),
                                      title = "Avg Film Length"), 
                              y = alt.Y(ycol, 
                                title = "Film Rating"))

    return  backup.to_html()

# %%
app = Dash(__name__)

app.layout = html.Div([
        dcc.Dropdown(
            id='ycol', value={'rating'},
            options=[{'label': i, 'value': i} for i in bk_df.columns]),
        html.Iframe(
            id='scatter',
            style={'border-width': '0', 'width': '100%', 'height': '400px'},
            srcDoc=plot_bkup(ycol='rating'))])

# @app.callback(
#     Output('scatter', 'srcDoc'),
#     Input('ycol', 'value'))

def update_output(ycol):
    return plot_bkup(ycol)

if __name__ == '__main__':
    app.run_server(
        port = 8071,
        debug=False)
# Out:
# Dash is running on http://127.0.0.1:8071/
#
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8071/ (Press CTRL+C to quit)
# 127.0.0.1 - - [05/Mar/2022 16:26:35] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Mar/2022 16:26:35] "GET /_dash-dependencies HTTP/1.1" 200 -
# Exception on /_dash-layout [GET]
# Traceback (most recent call last):
#   File "/Users/jasmineortega/opt/miniconda3/envs/532/lib/python3.10/site-packages/flask/app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/jasmineortega/opt/miniconda3/envs/532/lib/python3.10/site-packages/flask/app.py", line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
# ...
